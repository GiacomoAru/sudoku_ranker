# %%
from pathlib import Path
import random
import sys
import time

import matplotlib.pyplot as plt
import pandas as pd

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "sudoku_app").is_dir():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "sudoku_app").is_dir():
    raise RuntimeError("Avvia Jupyter dalla cartella del progetto o da notebooks/")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from sudoku_app.archive import repository as sa
from sudoku_app.core import visualization as sv

sa.configure_archive("offline")

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
008070040200000005010000300000030100004500070000009006070040080500200000003006009
"""
puzzle = sa.normalise_sudoku_grid(puzzle)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()

# %%
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    "unsolvable",
    "tag",
    ""
)

# %%
sa.delete_sudoku("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sa.delete_sudoku("")
#
# File c:\Users\cicci\Desktop\workspaces\sudoku\sudoku_app\archive\repository.py:1293, in delete_sudoku(reference)
#    1278 def delete_sudoku(reference):
#    1279     """
#    1280     Elimina completamente un Sudoku concreto dall'archivio.
#    1281
#    (...)   1291     classe canonica. Un riferimento inesistente solleva ``FileNotFoundError``.
#    1292     """
# -> 1293     path = _resolve_puzzle_path(reference)
#    1294     resolved_path = path.resolve()
#    1295     puzzles_root = SUDOKU_PUZZLES_DIR.resolve()
#
# File c:\Users\cicci\Desktop\workspaces\sudoku\sudoku_app\archive\repository.py:1061, in _resolve_puzzle_path(reference)
#    1055 if len(matching_paths) > 1:
#    1056     raise ValueError(
#    1057         f"Esistono più Sudoku con il nome {reference!r}. "
#    1058         "Usa il loro identificatore."
#    1059     )
# -> 1061 raise FileNotFoundError(
#    1062     f"Sudoku non trovato: {reference!r}."
#    1063 )
#
# FileNotFoundError: Sudoku non trovato: ''.
