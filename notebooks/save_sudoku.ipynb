# %%
from pathlib import Path
import random
import sys
import time

import matplotlib.pyplot as plt
import pandas as pd

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "sudoku_app").is_dir():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "sudoku_app").is_dir():
    raise RuntimeError("Avvia Jupyter dalla cartella del progetto o da notebooks/")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from sudoku_app.archive import repository as sa
from sudoku_app.core import visualization as sv

sa.configure_archive("offline")

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
870290301506000000013067005100000700607000803008000004700910620000000509902036047
"""
puzzle = sa.normalise_sudoku_grid(puzzle)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()

# %%
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    provenience="settimana_sudoku",
    tag="24_07_2026",
    difficulty="sfida",
)

# %%
sa.delete_sudoku("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sa.delete_sudoku("")
#
# File c:\Users\cicci\Desktop\workspaces\sudoku\sudoku_app\archive\repository.py:1095, in delete_sudoku(reference)
#    1080 def delete_sudoku(reference):
#    1081     """
#    1082     Elimina completamente un Sudoku concreto dall'archivio.
#    1083
#    (...)   1093     classe canonica. Un riferimento inesistente solleva ``FileNotFoundError``.
#    1094     """
# -> 1095     path = _resolve_puzzle_path(reference)
#    1096     resolved_path = path.resolve()
#    1097     puzzles_root = SUDOKU_PUZZLES_DIR.resolve()
#
# File c:\Users\cicci\Desktop\workspaces\sudoku\sudoku_app\archive\repository.py:910, in _resolve_puzzle_path(reference)
#     904 if len(matching_paths) > 1:
#     905     raise ValueError(
#     906         f"Esistono più Sudoku con il nome {reference!r}. "
#     907         "Usa il loro identificatore."
#     908     )
# --> 910 raise FileNotFoundError(
#     911     f"Sudoku non trovato: {reference!r}."
#     912 )
#
# FileNotFoundError: Sudoku non trovato: ''.
