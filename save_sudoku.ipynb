# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

import sudoku_archive as sa
import sudoku_visualization as sv

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
205090000000103000000070005400005000006000302000000601800000000030400700071060400
"""
puzzle = sa.normalise_sudoku_grid(puzzle)
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    provenience="coach",
    tag="campain",
    difficulty="mh",
)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()
