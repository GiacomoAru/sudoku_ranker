# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

import sudoku_archive as sa
import sudoku_visualization as sv

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
500200410030000000000050900009400000073000060600109030002000807000001040800000200
"""
puzzle = sa.normalise_sudoku_grid(puzzle)
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    provenience="coach",
    tag="campain",
    difficulty="m",
)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()
