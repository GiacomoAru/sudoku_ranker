# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

import sudoku_archive as sa
import sudoku_visualization as sv

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
040708000008300012000000000509000460016040000800072000001080070002000008000000296
"""
puzzle = sa.normalise_sudoku_grid(puzzle)
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    provenience="coach",
    tag="campain",
    difficulty="m",
)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()
