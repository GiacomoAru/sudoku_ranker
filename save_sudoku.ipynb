# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

import sudoku_archive as sa
import sudoku_visualization as sv

"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
800000067
050408109
006079340
060052890
003804200089630070012980700705106080940000001
"""
puzzle = sa.normalise_sudoku_grid(puzzle)
saved_info = sa.save_with_standard_nomenclature(
    puzzle,
    provenience="settimana_sudoku",
    tag="24_07_2026",
    difficulty="facile",
)

# %%
sv.draw_grid(
    puzzle,
)
plt.show()

# %%
sa.delete_sudoku("8599ddac3898796b83f0")
# Out:
# {'deleted': True,
#  'id': '8599ddac3898796b83f0',
#  'name': 'settimana_sudoku_relax_1',
#  'canonical_id': '5709e3f7117e23ed237feb9623d23b16564ca582a88e319df583c26fcb747fea',
#  'deleted_puzzle_path': WindowsPath('C:/Users/cicci/Desktop/workspaces/sudoku/sudoku_data/puzzles/8599ddac3898796b83f0.json'),
#  'deleted_analysis_directory': WindowsPath('C:/Users/cicci/Desktop/workspaces/sudoku/sudoku_data/analyses/8599ddac3898796b83f0'),
#  'deleted_analysis_file_count': 1,
#  'cleared_memory_cache_entry_count': 0,
#  'canonical_class_deleted': True,
#  'remaining_isomorphic_variant_ids': [],
#  'remaining_isomorphic_variant_count': 0}
