# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

import sudoku_solver as ss
import sudoku_archive as sa
import sudoku_visualization as sv
import sudoku_generator as sg

i = 0
"""
000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000

000 000 000
000 000 000
000 000 000
"""
# Out:
# '\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n\n000 000 000\n000 000 000\n000 000 000\n'

# %%
puzzle = """
009000000260010000030002010000089040090100007000430005400900006007000000010000420
"""
puzzle = sa.parse_sudoku(puzzle)
puzzle_name = f'coach_hell_0'
i+= 1

# %%
sv.draw_grid(
    puzzle,
    title=puzzle_name,
)
plt.show()

# %%
saved_info = sa.save_sudoku(
    puzzle,
    name=puzzle_name,
    metadata={
        "provenienza": "coach",
    },
)
